# %%
print("Hello world !")
# Out:
# Hello world !

# %%
#introduction to variables

# %%
x=4
y=5
x+y
# Out:
# 9

# %%
# Dclaration of variables

# %%
#1

# %%
first name="dipak"
print(first name)
# Out:
#   File "<ipython-input-4-a54b69d092f3>", line 1
#     first name="dipak"
#              ^
# SyntaxError: invalid syntax

# %%
first_name="dipak"
print(first_name)
# Out:
# dipak

# %%
#2

# %%
1name="dipak"
print(1name)
# Out:
#   File "<ipython-input-6-b550ffcb520e>", line 1
#     1name="dipak"
#         ^
# SyntaxError: invalid syntax

# %%
name1="dipak"
print(name1)
# Out:
# dipak

# %%
#3

# %%
na%m="dipak"
print(na%m)
# Out:
#   File "<ipython-input-8-943583c661bb>", line 1
#     na%m="dipak"
#                 ^
# SyntaxError: can't assign to operator

# %%
#How to define string

# %%
#1 with single quote

# %%
name='dipak'
print(name)
# Out:
# dipak

# %%
#2 with double quote

# %%
name="dipak"
print(name)
# Out:
# dipak

# %%
#3 with triple quote

# %%
name='''dipak'''
print(name)
# Out:
# dipak

# %%
#type()

# %%
type(name)
# Out:
# str
